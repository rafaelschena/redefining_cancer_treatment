# %% [markdown]
# # Redução de dimensionalidade
# Nesta etapa será feita a redução de dimensionalidade antes do treinamento dos modelos de machine learning.

# %%
import numpy as np
from sklearn.decomposition import SparsePCA
from scipy import sparse

# %%
from google.colab import drive

# %%
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !ls -la drive/MyDrive/'Colab Notebooks'/
# Out:
# total 100155
# -rw------- 1 root root     7049 Dec 20 23:36 05-Reducao_dimensionalidade.ipynb
# -rw------- 1 root root 11033425 Dec 20 23:21 X_test_sparse.npz
# -rw------- 1 root root 91517217 Dec 18 18:27 X_train_blc_sparse.npz

# %%
X_train_blc_sparse = sparse.load_npz('drive/MyDrive/''Colab Notebooks''/X_train_blc_sparse.npz')

# %%
type(X_train_blc_sparse)
# Out:
# scipy.sparse.coo.coo_matrix

# %%
X_train_balanced = X_train_blc_sparse.toarray()

# %%
type(X_train_balanced)
# Out:
# numpy.ndarray

# %%
X_train_balanced.shape
# Out:
# (5877, 57156)

# %% [markdown]
# ## Decomposição com o método PCA
# Foi aplicado o método de *principal component analysis (PCA)* para redução de dimensionalidade do dataset de treino.

# %%
pca = SparsePCA(n_components=500)

# %%
X_train_pca = pca.fit_transform(X_train_balanced)

# %%
X_train_pca.shape
# Out:
# (5877, 500)

# %%
# Mesma sequência de operações com o dataset de teste

# %%
X_test_sparse = sparse.load_npz('drive/MyDrive/''Colab Notebooks''/X_test_sparse.npz')

# %%
X_test = X_test_sparse.toarray()

# %%
type(X_test)
# Out:
# numpy.ndarray

# %%
X_test.shape
# Out:
# (997, 57156)

# %%
X_test_pca = pca.fit_transform(X_test)

# %%
X_test_pca.shape
# Out:
# (997, 500)

# %% [markdown]
# ## Salvando os resultados de X_train_pca e X_test_pca para entrada no treinamento dos modelos de ML

# %%
np.savetxt('drive/MyDrive/''Colab Notebooks''/X_train_pca.csv', X_train_pca, delimiter=',')

# %%
np.savetxt('drive/MyDrive/''Colab Notebooks''/X_test_pca.csv', X_test_pca, delimiter=',')
